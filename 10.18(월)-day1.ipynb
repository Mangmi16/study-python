# %%
print('song')  #따온표 문자열로 인식
# Out:
# song

# %%
# print("파이썬에서는 print 코드를 사용해서 출력한다.") #주석
# print("파이썬에서는 print 코드를 사용해서 출력한다.")
# print("파이썬에서는 print 코드를 사용해서 출력한다.")
# Out:
# 파이썬에서는 print 코드를 사용해서 출력한다.
# 파이썬에서는 print 코드를 사용해서 출력한다.

# %%
print ('Hellow'+' '+'python')

# %%
print (2+5)
# Out:
# 7

# %%
print ('2'*3*10)
# Out:
# ...

# %%
#입력 input() - 사용자에게서 입력값을 받아온다.

# %%
print ('Hellow'+' '+'python')
print (input("안녕은영어로?")+'python')
# Out:
# Hellow python
# 안녕은영어로?hellow
# hellowpython

# %%
#Python 규칙
- case sensitive (대소문자 구분 철저히) : Python python
- indent sensitive (맨 앞줄 띄어쓰기 : 들여쓰기)
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7392/500068026.py", line 2
#     - case sensitive (대소문자 구분 철저히) : Python python
#            ^
# SyntaxError: invalid syntax

# %%
hellowPython = 100
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7392/1557246964.py in <module>
#       1 hellowPython = 100
# ----> 2 print(A)
#
# NameError: name 'A' is not defined

# %%
if 조건 :
    실행문장
for 조건 :
    실행문장
def 조건 :
    실행문장
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7392/2046567652.py", line 3
#     for 조건 :
#            ^
# SyntaxError: invalid syntax

# %%
### 변수 :값을 담아주는 그릇.
규칙:
    숫자먼저 올 수 없다.
    대소문자 구분
    파이썬 예약 언어 변수 사용 불가
변수_문자 = "Hellow Python"
변수_숫자 = 100
변수3 = 변수_숫자
variable = 변수_숫자
Variable = 변수_숫자
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7392/2978745817.py", line 2
#     규칙:
#        ^
# SyntaxError: invalid syntax

# %%
변수_문자 = "Hellow Python"
변수_숫자 = 100
변수3 = 변수_숫자
variable = 변수_숫자
Variable = 변수_숫자

# %%
num1 = '3'
num2 = '10'

print(num1+unm2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7392/228664639.py in <module>
#       2 num2 = '10'
#       3
# ----> 4 print(num1+unm2)
#
# NameError: name 'unm2' is not defined

# %%
str1 = 'Hellow'
str2 = "Python"

print(str1+' ' str2)
print("안녕은 영어로:" ,str2)
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7324/3165091793.py", line 4
#     print(str1+' ' str2)
#                    ^
# SyntaxError: invalid syntax

# %%
menu = input("뭐 먹을까?")
# Out:
# 뭐 먹을까? 돈까스

# %%
# Out:
# 이름을 입력하세요 서진수
# ' 서진수'

# %%
# Out:
# 취미를 입력하세요 낚시
# ' 낚시'

# %%
변수1 = input('이름을 입력하세요')
변수 = input('취미를 입력하세요')

print(변수1+'의 취미는'+ 변수+'입니다.'
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_3088/3975552531.py", line 4
#     print(변수1+'의 취미는'+ 변수+'입니다.'
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
변수1 = input('이름을 입력하세요')
변수 = input('취미를 입력하세요')
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_5520/2491186354.py", line 3
#     print(변수1+'님의 취미는'+변수+'입니다.'')
#                                   ^
# SyntaxError: EOL while scanning string literal

# %%
print("%s님의 취미는 %s입니다,"  %(변수1,변수))
# Out:
# song님의 취미는 낚시입니다,

# %%
이름 = input('이름을 입력하세요')
취미 = input('취미를 입력하세요')

print('%s'님의 취미는 '%s'입니다.') %(이름,취미))
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_5520/2433323859.py", line 4
#     print('%s'님의 취미는 '%s'입니다.') %(이름,취미))
#               ^
# SyntaxError: invalid syntax

# %%
지역 = input("지역을 입력하세요 ")
인원 = input("인원을 입력하세요 ")

print ("여행하실 지역은 '%s'이고 총 인원수는 '%s'입니다." %(지역,인원))
# Out:
# 지역을 입력하세요 부산
# 인원을 입력하세요 4
# 여행하실 지역은 '부산'이고 총 인원수는 '4'입니다.

# %%
print("3의 8승은?" , 3**8)

no1 = 3
no2 = 8
no3 = 6561
print('%s의 %s 승은? %s' %(no1,no2,no3))

print('3의 8승은? : %s' %(no1**no2))
# Out:
# 3의 8승은? 6561
# 3의 8 승은? 6561
# 3의 8승은? : 6561

# %%
no1 = int(input('첫 번째 값을 입력하세요 '))
no2 = int(input('두 번째 값을 입력하세요 '))

print('= %s' %(no1+no2))
# Out:
# 첫 번째 값을 입력하세요 2
# 두 번째 값을 입력하세요 5
# = 7

# %%
###함수(funtion, fn) :특정 task를 실행하기 위해 만들어진 명력어 블럭

#round(실수,몇번째 자리까지 반올림 할 것인가) 반올림을 해준다. 실수 float 정수 int


실수1 = 0.231678

round(실수1,3)

정수1 = 3
정수2 = 6

round(정수1/정수2,3)

round(float(input("실수를 입력하세요")),3)
# Out:
# 실수를 입력하세요3.25
# 3.25

# %%
#trunc() - 내림 
#import 모듈이름
import math
정수1 = 3
정수2 = 8
# 특정 모듈에서 특정함수를 불러올 때
#모듈이름.함수

math.trunc(정수2/정수1)
# Out:
# 2

# %%
#ceil() 올림 ceilling = 천장

import math

no1 = 31.3

math.ceil(no1)
# Out:
# 32

# %% [markdown]
# ### floor가장가까운 정수중에 작은 수
# from math.세부모듈명 import ceil

# %%
import math
math.trunc(-3.62)
# Out:
# -3

# %%
import math
math.floor(-3.62)
# Out:
# -4

# %%
import math
no = -3.62
print(math.trunc(no))
print(math.floor(no))
# Out:
# -3
# -4

# %% [markdown]
# ### 문자열

# %%
str1 = "파이썬완전쉽죠?"

# index 값은 0부터 시작한다.

str1[1]

#범위를 정해줄 때 : 시작값은 포함(inclusive) 끝값은 불포함(de)
str1[1:4]
# Out:
# '이썬완'

# %% [markdown]
# ### :의 역할
# * str1[1:4] 1 부터 3까지
# * str1[1:]  1부터 끝까지
# * str1[:4]   0부터 3까지

# %%
str1 = "파이썬완전쉽죠?"
str1[:6]
# Out:
# '파이썬완전쉽'

# %%
str1 = "파이썬완전쉽죠?"
str1[0:]
# Out:
# '파이썬완전쉽죠?'

# %%
# lower() : 전부 소문자  /  upper() 전부 대문자

str2 = "PyThon"
print(str2.lower())
print(str2.upper())

str2.upper().lower()
# Out:
# python
# PYTHON
# 'python'

# %%
#strip()
#문법 변수.strip()

str3 = "                   공백으로   가득  한  문  장        "

str3.strip()
# Out:
# '공백으로   가득  한  문  장'

# %%
#lstrip() 왼쪽
str3 = "                   공백으로   가득  한  문  장        "

str3.lstrip()
# Out:
# '공백으로   가득  한  문  장        '

# %%
#rstrip() 오른쪽

str3 = "                   공백으로   가득  한  문  장        "

str3.rstrip()
# Out:
# '                   공백으로   가득  한  문  장'

# %%
#replace ("바꿔줄 대상","새 문자")
str4 = "새우깡은 해산물이다"
str4.replace("새우깡은","새우는")
# Out:
# '새우는 해산물이다'

# %%
str3 = "                   공백으로   가득  한  문  장        "
str3.replace(" ","")
# Out:
# '공백으로가득한문장'

# %%
#split() 나누다, 쪼개다. <- 기준을 중심으로 문자열을 나누어

str5 = "vlwk9797@gmail.com"
str5.split('@')
# Out:
# ['vlwk9797', 'gmail.com']

# %%
#len() : 요소의 개수를 계산
#\n = 엔터 요소 1개

str1 = "파이썬 완전쉽죠?\n"
len(str1)
# Out:
# 10
